# %%
print("hello")
# Out:
# hello

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
print("pandas insgtall")
# Out:
# pandas insgtall

# %%
print("helo")
# Out:
# helo

# %%
print("hello ")
# Out:
# hello
